# %% [markdown]
# <a href="https://colab.research.google.com/github/DianaRivas98/Proyecto-Big-Data/blob/main/Proyecto_BigData___1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rpy2

# %%
# %load_ext rpy2.ipython

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
url= '/content/drive/MyDrive/Big_Data/Proyecto_Big_Data_(1).xlsx'

# %%
import pandas as pd
df=pd.read_excel(url)

# %%
df.head()
# Out:
#    Unnamed: 0                                       Title  \
# 0           0                                      Avatar
# 1           1                           Avengers: Endgame
# 2           2                    Avatar: The Way of Water
# 3           3                                     Titanic
# 4           4  Star Wars: Episode VII - The Force Awakens
#
#                                           Movie Info  Year  \
# 0  A paraplegic Marine dispatched to the moon Pan...  2009
# 1  After the devastating events of Avengers: Infi...  2019
# 2  Jake Sully lives with his newfound family form...  2022
# 3  A seventeen-year-old aristocrat falls in love ...  1997
# 4  As a new threat to the galaxy rises, Rey, a de...  2015
#
#                            Distributor                 Budget (in $)  \
# 0                Twentieth Century Fox                     237000000
# 1  Walt Disney Studios Motion Pictures                     356000000
# ...

# %%
df['Year'] = df['Year'].astype(int)

# %%
df.describe()
# Out:
#         Unnamed: 0         Year  Domestic Sales (in $)  \
# count  1000.000000   995.000000           9.950000e+02
# mean    499.500000  2008.167839           1.648976e+08
# std     288.819436    10.601003           1.199746e+08
# min       0.000000  1937.000000           6.752000e+03
# 25%     249.750000  2002.000000           9.585548e+07
# 50%     499.500000  2010.000000           1.351891e+08
# 75%     749.250000  2016.000000           1.987321e+08
# max     999.000000  2023.000000           9.366622e+08
#
#        International Sales (in $)  World Wide Sales (in $)
# count                9.950000e+02             9.950000e+02
# mean                 2.646278e+08             4.236093e+08
# std                  2.137490e+08             3.060077e+08
# min                  2.450000e+07             1.799689e+08
# 25%                  1.327110e+08             2.276657e+08
# 50%                  1.946035e+08             3.197157e+08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1000 non-null   int64
#  1   Title                       1000 non-null   object
#  2   Movie Info                  1000 non-null   object
#  3   Year                        1000 non-null   int64
#  4   Distributor                 994 non-null    object
#  5   Budget (in $)               995 non-null    object
#  6   Domestic Opening (in $)     995 non-null    object
#  7   Domestic Sales (in $)       995 non-null    float64
#  8   International Sales (in $)  995 non-null    float64
#  9   World Wide Sales (in $)     1000 non-null   int64
#  10  Release Date                995 non-null    object
#  11  Genre                       995 non-null    object
#  12  Running Time                995 non-null    object
# ...

# %%
# %%R
# install.packages("tidyverse")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/tidyverse_2.0.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 704618 bytes (688 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# %%R
# library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# %%R
#  install.packages("dplyr")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/dplyr_1.1.3.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 1083635 bytes (1.0 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# %%R
# library ("dplyr")

# %%
# %%R
# data(df)

# %%
# %%R
#
# df%>%head()
# Out:
#
# 1 function (x, df1, df2, ncp, log = FALSE)
# 2 {
# 3     if (missing(ncp))
# 4         .Call(C_df, x, df1, df2, log)
# 5     else .Call(C_dnf, x, df1, df2, ncp, log)
# 6 }

# %%
filtered1_df = df[df['Year'] == 2015]

# %%
filtered2_df = df[df['Genre'] == "Action"]

# %%
filtered3_df = df[df['Running Time'] == "2 hr 8 min "]

# %%
filtered_df = df[df['International Sales (in $)']=="2.138484e+09"]

# %%
print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Movie Info, Year, Distributor, Budget (in $), Domestic Opening (in $), Domestic Sales (in $), International Sales (in $), World Wide Sales (in $), Release Date, Genre, Running Time, License]
# Index: []

# %%
print(filtered1_df)
# Out:
#      Unnamed: 0                                       Title  \
# 4             4  Star Wars: Episode VII - The Force Awakens
# 7             7                              Jurassic World
# 10           10                                   Furious 7
# 14           14                     Avengers: Age of Ultron
# 25           25                                     Minions
# 77           77                                     Spectre
# 86           86                                  Inside Out
# 149         149          Mission: Impossible - Rogue Nation
# 162         162       The Hunger Games: Mockingjay - Part 2
# 167         167                                 The Martian
# 194         194                        Fifty Shades of Grey
# 212         212                                  Cinderella
# 218         218                                The Revenant
# 232         232                                     Ant-Man
# 260         260                        Hotel Transylvania 2
# ...

# %%
print(filtered2_df)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Movie Info, Year, Distributor, Budget (in $), Domestic Opening (in $), Domestic Sales (in $), International Sales (in $), World Wide Sales (in $), Release Date, Genre, Running Time, License]
# Index: []

# %%
print(filtered3_df)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Movie Info, Year, Distributor, Budget (in $), Domestic Opening (in $), Domestic Sales (in $), International Sales (in $), World Wide Sales (in $), Release Date, Genre, Running Time, License]
# Index: []

# %%
filtered_df = df[(df['Year'] >= 2015) & (df['Year'] <= 2018)]

# %%
print(filtered_df)
# Out:
#      Unnamed: 0                                       Title  \
# 4             4  Star Wars: Episode VII - The Force Awakens
# 7             7                              Jurassic World
# 10           10                                   Furious 7
# 14           14                     Avengers: Age of Ultron
# 25           25                                     Minions
# 77           77                                     Spectre
# 86           86                                  Inside Out
# 149         149          Mission: Impossible - Rogue Nation
# 162         162       The Hunger Games: Mockingjay - Part 2
# 167         167                                 The Martian
# 194         194                        Fifty Shades of Grey
# 212         212                                  Cinderella
# 218         218                                The Revenant
# 232         232                                     Ant-Man
# 260         260                        Hotel Transylvania 2
# ...
